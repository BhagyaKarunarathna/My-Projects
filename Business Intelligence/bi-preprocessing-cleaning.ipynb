# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Books Rating Dataframe

# %% [markdown]
# This file has information about 3M book reviews for 212404 unique book and users who gives these reviews for each book.

# %%
df_rating = pd.read_csv("/kaggle/input/amazon-books-reviews/Books_rating.csv")
df_rating.head()
# Out:
#            Id                           Title  Price         User_id  \
# 0  1882931173  Its Only Art If Its Well Hung!    NaN   AVCGYZL8FQQTD
# 1  0826414346        Dr. Seuss: American Icon    NaN  A30TK6U7DNS82R
# 2  0826414346        Dr. Seuss: American Icon    NaN  A3UH4UZ4RSVO82
# 3  0826414346        Dr. Seuss: American Icon    NaN  A2MVUWT453QH61
# 4  0826414346        Dr. Seuss: American Icon    NaN  A22X4XUPKF66MR
#
#                           profileName review/helpfulness  review/score  \
# 0               Jim of Oz "jim-of-oz"                7/7           4.0
# 1                       Kevin Killian              10/10           5.0
# 2                        John Granger              10/11           5.0
# 3  Roy E. Perry "amateur philosopher"                7/7           4.0
# 4     D. H. Richards "ninthwavestore"                3/3           4.0
#
#    review/time                                   review/summary  \
# 0    940636800           Nice collection of Julie Strain images
# 1   1095724800                                Really Enjoyed It
# 2   1078790400  Essential for every personal and Public Library
# 3   1090713600  Phlip Nel gives silly Seuss a serious treatment
# 4   1107993600                           Good academic overview
#
#                                          review/text
# 0  This is only for Julie Strain fans. It's a col...
# 1  I don't care much for Dr. Seuss but after read...
# 2  If people become the books they read and if "t...
# 3  Theodore Seuss Geisel (1904-1991), aka &quot;D...
# 4  Philip Nel - Dr. Seuss: American IconThis is b...

# %%
df_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000000 entries, 0 to 2999999
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Id                  object
#  1   Title               object
#  2   Price               float64
#  3   User_id             object
#  4   profileName         object
#  5   review/helpfulness  object
#  6   review/score        float64
#  7   review/time         int64
#  8   review/summary      object
#  9   review/text         object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 228.9+ MB

# %% [markdown]
# ## 1. **Data Cleaning and Preprocessing**
#    - *Objective*: Prepare the dataset for analysis by handling missing values, correcting data inconsistencies, and transforming data into a usable format.
#    - *Business Value*: Ensures high-quality data for analysis, leading to more accurate and reliable results.
#    - *Approach*: Implement data cleaning operations such as filling missing values, removing duplicates, normalizing text data, and encoding categorical variables.

# %%
# Check for duplicates
df_rating.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 2999995    False
# 2999996    False
# 2999997    False
# 2999998    False
# 2999999    False
# Length: 3000000, dtype: bool

# %%
# Count the number of duplicate rows
duplicate_count = df_rating.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 8774

# %%
# Remove duplicates
df_rating.drop_duplicates(inplace = True)

duplicate_count = df_rating.duplicated().sum()
print(f"Number of duplicate rows after removing duplicates: {duplicate_count}")
print('There are {} rows and {} columns in the dataframe after removing duplicates.'.format(df_rating.shape[0],df_rating.shape[1]))
# Out:
# Number of duplicate rows after removing duplicates: 0
# There are 2991226 rows and 10 columns in the dataframe after removing duplicates.

# %%
# Check for missing values
missing_values = df_rating.isnull().sum()
print(missing_values)
# Out:
# Id                          0
# Title                     208
# Price                 2510854
# User_id                558559
# profileName            558677
# review/helpfulness          0
# review/score                0
# review/time                 0
# review/summary            407
# review/text                 8
# dtype: int64

# %%
# List of columns to drop
columns_to_drop = ['Id', 'User_id', 'profileName', 'review/time']

# Drop the unnecessary columns with null values
df_rating = df_rating.drop(columns=columns_to_drop)

df_rating.columns
# Out:
# Index(['Title', 'Price', 'review/helpfulness', 'review/score',
#        'review/summary', 'review/text'],
#       dtype='object')

# %%
# Remove rows where the null value count is insignificant
df_rating.dropna(subset=['Title', 'review/summary', 'review/text'], inplace = True)

missing_values = df_rating.isnull().sum()
print("Missing values:\n", missing_values)
# Out:
# Missing values:
#  Title                       0
# Price                 2510275
# review/helpfulness          0
# review/score                0
# review/summary              0
# review/text                 0
# dtype: int64

# %%
print('There are {} rows and {} columns in the dataframe after removing null values.'.format(df_rating.shape[0],df_rating.shape[1]))
# Out:
# There are 2990603 rows and 6 columns in the dataframe after removing null values.

# %%
# Lowecasing & Removing punctuations and stopwords & Lemmatization

#Libraries for formattting and handling text 
import string
import re

#Library for nltk
import nltk 
import nltk.corpus
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
from nltk.stem import WordNetLemmatizer
from wordcloud import WordCloud

from collections import defaultdict
from collections import  Counter
stop=set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Lowercase, punctuations and stopwords
nltk.download('stopwords')

# Get the stopwords list
stop_words = set(stopwords.words('english'))

def clean_text(text):
    text = str(text).lower()  # Converts text to lowercase
    text = re.sub('\d+', '', text)  # Removes numbers
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)  # Removes punctuations
    
    # Split text into words
    words = text.split()
    
    # Remove stopwords
    words = [word for word in words if word not in stop_words]
    
    # Join words back into a single string
    text = ' '.join(words)
    
    return text
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Apply clean_text function to the 'review/summary' column
df_rating['Cleaned review/summary'] = df_rating['review/summary'].apply(clean_text)
df_rating[['review/summary', 'Cleaned review/summary']].head()
# Out:
#                                     review/summary  \
# 0           Nice collection of Julie Strain images
# 1                                Really Enjoyed It
# 2  Essential for every personal and Public Library
# 3  Phlip Nel gives silly Seuss a serious treatment
# 4                           Good academic overview
#
#                           Cleaned review/summary
# 0            nice collection julie strain images
# 1                                 really enjoyed
# 2        essential every personal public library
# 3  phlip nel gives silly seuss serious treatment
# 4                         good academic overview

# %%
# Apply clean_text function to the 'review/text' column
df_rating['Cleaned review/text'] = df_rating['review/text'].apply(clean_text)
df_rating[['review/text','Cleaned review/text']].head()
# Out:
#                                          review/text  \
# 0  This is only for Julie Strain fans. It's a col...
# 1  I don't care much for Dr. Seuss but after read...
# 2  If people become the books they read and if "t...
# 3  Theodore Seuss Geisel (1904-1991), aka &quot;D...
# 4  Philip Nel - Dr. Seuss: American IconThis is b...
#
#                                  Cleaned review/text
# 0  julie strain fans collection photos pages wort...
# 1  dont care much dr seuss reading philip nels bo...
# 2  people become books read child father man dr s...
# 3  theodore seuss geisel aka quotdr seussquot one...
# 4  philip nel dr seuss american iconthis basicall...

# %%
# Lemmatization

# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in /opt/conda/lib/python3.10/site-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /opt/conda/lib/python3.10/site-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.10/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.10/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/conda/lib/python3.10/site-packages (from spacy) (2.8.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from spacy) (70.0.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /opt/conda/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->spacy) (3.1.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /opt/conda/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/conda/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /opt/conda/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /opt/conda/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.10/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 51.5 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /opt/conda/lib/python3.10/site-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.8.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (70.0.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /opt/conda/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /opt/conda/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/conda/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /opt/conda/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /opt/conda/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.10/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
import pandas as pd

# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# Define the function to lemmatize a batch of texts
def lemmatize_text_batch(texts):
    docs = list(nlp.pipe(texts, batch_size=1000))
    lemmatized_texts = [' '.join([token.lemma_ for token in doc if not token.is_punct]) for doc in docs]
    return lemmatized_texts

# Define the function to process in batches and update the DataFrame
def process_in_batches_v2_multiple_columns(df, input_columns, output_columns, batch_size):
    for start in range(0, len(df), batch_size):
        end = min(start + batch_size, len(df))
        batch = df.loc[start:end, input_columns]
        
        # Print a sample of the data before lemmatization
        print(f"Processing rows {start} to {end}...")
        for i, col in enumerate(input_columns):
            print(f"Sample before lemmatization from column '{col}':")
            print(batch[col].head(2))  # Print the first 2 entries for brevity
        
        # Process each column separately
        for i, col in enumerate(input_columns):
            lemmatized_batch = lemmatize_text_batch(batch[col])
            df.loc[start:end, output_columns[i]] = lemmatized_batch
        
        # Print a sample of the data after lemmatization
        for i, col in enumerate(output_columns):
            print(f"Sample after lemmatization from column '{col}':")
            print(df.loc[start:end, col].head(2))  # Print the first 2 entries for brevity

    return df

# Apply the function to your DataFrame
batch_size = 500000  # Adjust as needed
input_columns = ['Cleaned review/summary', 'Cleaned review/text']
output_columns = ['Lemmatized review/summary', 'Lemmatized review/text']
df_rating = process_in_batches_v2_multiple_columns(df_rating, input_columns, output_columns, batch_size)
# Out:
# Processing rows 0 to 10000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 0    nice collection julie strain images
# 1                         really enjoyed
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 0    julie strain fans collection photos pages wort...
# 1    dont care much dr seuss reading philip nels bo...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 0    nice collection julie strain image
# 1                          really enjoy
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 0    julie strain fans collection photo page worth ...
# 1    do not care much dr seuss reading philip nel b...
# Name: Lemmatized review/text, dtype: object
# Processing rows 10000 to 20000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 10000    published long time ago still relevant today
# 10001                                           style
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 10000    subject solar energy topical today decades ago...
# 10001    book covers several generations generation rel...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 10000    publish long time ago still relevant today
# 10001                                         style
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 10000    subject solar energy topical today decade ago ...
# 10001    book cover several generation generation relea...
# Name: Lemmatized review/text, dtype: object
# Processing rows 20000 to 30000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 20000              much baffling boring
# 20001    absolutely best book ever read
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 20000    one spent years working drilling rigs colombia...
# 20001    wonderful imaginative seductively creatively w...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 20000                  much baffle bore
# 20001    absolutely good book ever read
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 20000    one spend year work drilling rig colombian jun...
# 20001    wonderful imaginative seductively creatively w...
# Name: Lemmatized review/text, dtype: object
# Processing rows 30000 to 40000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 30000         mice men
# 30001    great service
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 30000    great book unbeateable price outstanding servi...
# 30001    bought book one daughters school projects arri...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 30000        mouse man
# 30001    great service
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 30000    great book unbeateable price outstanding servi...
# 30001    buy book one daughter school project arrive ti...
# Name: Lemmatized review/text, dtype: object
# Processing rows 40000 to 50000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 40000                      quotgreat awsome fantasticquot
# 40001    excellent book animal lovers amp fans jeffs show
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 40000    great theres really nothing say wondering tho ...
# 40001    fan jeff corwin experience eagerly bought book...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 40000                    quotgreat awsome fantasticquot
# 40001    excellent book animal lover amp fans jeff show
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 40000    great there s really nothing say wonder tho bo...
# 40001    fan jeff corwin experience eagerly buy book fi...
# Name: Lemmatized review/text, dtype: object
# Processing rows 50000 to 60000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 50000            diverting journey tudor times
# 50001    atrocityone worse books ive ever read
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 50000    student teacher history approached novel littl...
# 50001    im still sure possessed read sure bunch people...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 50000              divert journey tudor time
# 50001    atrocityone bad book I ve ever read
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 50000    student teacher history approach novel little ...
# 50001    I m still sure possessed read sure bunch peopl...
# Name: Lemmatized review/text, dtype: object
# Processing rows 60000 to 70000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 60000    quite possibly best book ive read year
# 60001                               want sequel
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 60000    tendency find really good book drop everything...
# 60001    sahm amthis book give chuckles like real tears...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 60000    quite possibly good book I ve read year
# 60001                                want sequel
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 60000    tendency find really good book drop everything...
# 60001    sahm amthis book give chuckle like real tear j...
# Name: Lemmatized review/text, dtype: object
# Processing rows 70000 to 80000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 70000              goodtrilogy worth reading
# 70001    great realism horrid predictability
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 70000    friend recommended book others trilogy enjoyed...
# 70001    well immediately taken bookwormturnedreluctant...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 70000                 goodtrilogy worth read
# 70001    great realism horrid predictability
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 70000    friend recommend book other trilogy enjoy good...
# 70001    well immediately take bookwormturnedreluctanth...
# Name: Lemmatized review/text, dtype: object
# Processing rows 80000 to 90000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 80000    greatest work ever published
# 80001                     scary scary
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 80000    grand inquisitor dostoyevsky peak character in...
# 80001    agree taken dostoyevskys brothers karamazov di...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 80000    great work ever publish
# 80001                scary scary
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 80000    grand inquisitor dostoyevsky peak character in...
# 80001    agree take dostoyevskys brother karamazov dimi...
# Name: Lemmatized review/text, dtype: object
# Processing rows 90000 to 100000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 90000                                                great
# 90001    entertaining quotstoryquot prelude quotepic tr...
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 90000    hobbit time favorite book ive read least milli...
# 90001    serious intense lord rings intended semilighth...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 90000                                                great
# 90001    entertain quotstoryquot prelude quotepic trilo...
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 90000    hobbit time favorite book I ve read least mill...
# 90001    serious intense lord ring intend semilighthear...
# Name: Lemmatized review/text, dtype: object
# Processing rows 100000 to 110000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 100000    book review special person
# 100001      one best books ever read
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 100000    believe april morning pretty good novel book g...
# 100001    one best books ever read whole entire life tel...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 100000    book review special person
# 100001       one good book ever read
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 100000    believe april morning pretty good novel book g...
# 100001    one good book ever read whole entire life tell...
# Name: Lemmatized review/text, dtype: object
# Processing rows 110000 to 120000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 110000                   advertise
# 110001    treasure island treasure
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 110000    advertise nothing else say amazon enforce many...
# 110001    school teacher always looking resources use bo...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 110000                   advertise
# 110001    treasure island treasure
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 110000    advertise nothing else say amazon enforce many...
# 110001    school teacher always look resource use book t...
# Name: Lemmatized review/text, dtype: object
# Processing rows 120000 to 130000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 120000                  great combinations ideas
# 120001    great want pizza crammed lots toppings
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 120000    shea taken concept pizza steps farther cookboo...
# 120001    comes pizza two basic preferences either go so...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 120000               great combination idea
# 120001    great want pizza cram lot topping
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 120000    shea take concept pizza step far cookbook I ve...
# 120001    come pizza two basic preference either go some...
# Name: Lemmatized review/text, dtype: object
# Processing rows 130000 to 140000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 130000                motivational insightful
# 130001    absolutely beautiful truly work art
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 130000    comes deep inspirational john steinbeck compet...
# 130001    john steinbecks east eden truly work art blend...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 130000                motivational insightful
# 130001    absolutely beautiful truly work art
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 130000    come deep inspirational john steinbeck competi...
# 130001    john steinbeck east eden truly work art blend ...
# Name: Lemmatized review/text, dtype: object
# Processing rows 140000 to 150000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 140000               lot repetitious words
# 140001    broad fascinating inspiring read
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 140000    author qualified discuss theme book obviously ...
# 140001    collapse vast review topics covered ideas pres...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 140000                lot repetitious word
# 140001    broad fascinating inspiring read
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 140000    author qualified discuss theme book obviously ...
# 140001    collapse vast review topic cover idea present ...
# Name: Lemmatized review/text, dtype: object
# Processing rows 150000 to 160000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 150000    disappointing
# 150001         excelent
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 150000    author dennis smith expected majority book wou...
# 150001    larry brown shares emotional trauma firefighte...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 150000    disappointing
# 150001         excelent
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 150000    author dennis smith expect majority book would...
# 150001    larry brown share emotional trauma firefighter...
# Name: Lemmatized review/text, dtype: object
# Processing rows 160000 to 170000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 160000    breathe fresh eyre
# 160001      cinderella story
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 160000    previously reviewed jasper ffordes eyre affair...
# 160001    first time ever heard jane eyre senior high sc...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 160000    breathe fresh eyre
# 160001      cinderella story
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 160000    previously review jasper fforde eyre affair st...
# 160001    first time ever hear jane eyre senior high sch...
# Name: Lemmatized review/text, dtype: object
# Processing rows 170000 to 180000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 170000    elegant tedious
# 170001            tedious
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 170000    suprisingly moving insightful book slow pacing...
# 170001    maxwells writing enjoyable restraint character...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 170000    elegant tedious
# 170001            tedious
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 170000    suprisingly move insightful book slow pacing f...
# 170001    maxwell write enjoyable restraint character ma...
# Name: Lemmatized review/text, dtype: object
# Processing rows 180000 to 190000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 180000    putting light darkness
# 180001                   suprise
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 180000    quotuncle toms cabinquot uplifting book read h...
# 180001    heard uncle toms cabin life finally decided re...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 180000    put light darkness
# 180001               suprise
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 180000    quotuncle tom cabinquot uplifting book read ho...
# 180001    hear uncle tom cabin life finally decide read ...
# Name: Lemmatized review/text, dtype: object
# Processing rows 190000 to 200000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 190000                another incredible series
# 190001    another hit ballpark anyones universe
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 190000    said cultural history found italy rest world c...
# 190001    people nothing wrong far really interesting bo...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 190000               another incredible series
# 190001    another hit ballpark anyone universe
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 190000    say cultural history find italy rest world com...
# 190001    people nothing wrong far really interesting bo...
# Name: Lemmatized review/text, dtype: object
# Processing rows 200000 to 210000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 200000                 canonical masterpiece
# 200001    great translation relevant decades
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 200000    subtle yet consistent way book conveys main fl...
# 200001    ive read one translation dialectic one far bet...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 200000                canonical masterpiece
# 200001    great translation relevant decade
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 200000    subtle yet consistent way book convey main fla...
# 200001    I ve read one translation dialectic one far we...
# Name: Lemmatized review/text, dtype: object
# Processing rows 210000 to 220000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 210000      quite disappointing ending fantastic epic
# 210001    manual third millenium fascinating lifeless
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 210000    although well aware book one anwer questions s...
# 210001    undoubtedly clarkes scientific philosophical r...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 210000         quite disappointing end fantastic epic
# 210001    manual third millenium fascinating lifeless
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 210000    although well aware book one anwer question st...
# 210001    undoubtedly clarke scientific philosophical ru...
# Name: Lemmatized review/text, dtype: object
# Processing rows 220000 to 230000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 220000                             ummmmbeefy
# 220001    comedy tragedy matter fivestar book
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 220000    loved book love much itch sure humor little br...
# 220001    first time read confederacy ambivalent couldnt...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 220000                             ummmmbeefy
# 220001    comedy tragedy matter fivestar book
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 220000    love book love much itch sure humor little bro...
# 220001    first time read confederacy ambivalent could n...
# Name: Lemmatized review/text, dtype: object
# Processing rows 230000 to 240000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 230000    flashbacks great oral history
# 230001                       great book
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 230000    walter middleton gives great taste folksy oral...
# 230001    gives prospective events lower enlisted mans v...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 230000    flashback great oral history
# 230001                      great book
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 230000    walter middleton give great taste folksy oral ...
# 230001    give prospective event lower enlist man view r...
# Name: Lemmatized review/text, dtype: object
# Processing rows 240000 to 250000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 240000    griping
# 240001       whoa
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 240000           best thriller ever read could put read til
# 240001    fascinating story cant put pretty gory spots h...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 240000    gripe
# 240001     whoa
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 240000           good thriller ever read could put read til
# 240001    fascinating story can not put pretty gory spot...
# Name: Lemmatized review/text, dtype: object
# Processing rows 250000 to 260000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 250000                     elopers unite
# 250001    delightfully charming humorous
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 250000    plot novel detailed many reviews try repeat su...
# 250001    youre ever buy book keep hand sure lift spirit...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 250000                      eloper unite
# 250001    delightfully charming humorous
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 250000    plot novel detail many review try repeat suffi...
# 250001    you re ever buy book keep hand sure lift spiri...
# Name: Lemmatized review/text, dtype: object
# Processing rows 260000 to 270000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 260000    best science fiction bookthat ive read
# 260001    science fiction intellect never better
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 260000     simple sciencefiction book although may seem boo
# 260001    first read contact paperback form one first pa...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 260000    good science fiction bookthat I ve read
# 260001       science fiction intellect never well
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 260000     simple sciencefiction book although may seem boo
# 260001    first read contact paperback form one first pa...
# Name: Lemmatized review/text, dtype: object
# Processing rows 270000 to 280000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 270000            best aspect book cybil
# 270001    excellent account teenage girl
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 270000    lot trouble getting book first writing ireadse...
# 270001    read book couldnt believe author man andreas t...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 270000            good aspect book cybil
# 270001    excellent account teenage girl
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 270000    lot trouble get book first write ireadseventee...
# 270001    read book could not believe author man andreas...
# Name: Lemmatized review/text, dtype: object
# Processing rows 280000 to 290000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 280000              im happy product
# 280001    brilliant simply brilliant
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 280000    book delivered one advertised cover different ...
# 280001    oneill produces triumph turbulent bonds member...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 280000             I m happy product
# 280001    brilliant simply brilliant
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 280000    book deliver one advertise cover different goo...
# 280001    oneill produce triumph turbulent bond member t...
# Name: Lemmatized review/text, dtype: object
# Processing rows 290000 to 300000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 290000    favorite book
# 290001    terrific book
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 290000    bought motherinlaw birthday going trip told fa...
# 290001    douglas adams author hitchhikers guide thegala...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 290000    favorite book
# 290001    terrific book
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 290000    buy motherinlaw birthday go trip tell favorite...
# 290001    douglas adams author hitchhiker guide thegalax...
# Name: Lemmatized review/text, dtype: object
# Processing rows 300000 to 310000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 300000        sly witty
# 300001    thought great
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 300000    one books always keep bed reminder take seriou...
# 300001    ackerly naughty naughty man agree another revi...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 300000      sly witty
# 300001    think great
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 300000    one book always keep bed reminder take serious...
# 300001    ackerly naughty naughty man agree another revi...
# Name: Lemmatized review/text, dtype: object
# Processing rows 310000 to 320000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 310000    quotordinaryquot life captured
# 310001                               wow
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 310000    tumultuous birth tragedy accompanied daisy goo...
# 310001    written autobiography daisy goodwill flett who...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 310000    quotordinaryquot life capture
# 310001                              wow
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 310000    tumultuous birth tragedy accompany daisy goodw...
# 310001    write autobiography daisy goodwill flett whose...
# Name: Lemmatized review/text, dtype: object
# Processing rows 320000 to 330000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 320000                             discworld
# 320001    journey assassins guild handmaiden
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 320000    ive decided hes good prolific write brand new ...
# 320001    delightful piece discworld series must story d...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 320000                            discworld
# 320001    journey assassin guild handmaiden
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 320000    I ve decide he s good prolific write brand new...
# 320001    delightful piece discworld series must story d...
# Name: Lemmatized review/text, dtype: object
# Processing rows 330000 to 340000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 330000        perfect child
# 330001    great book summer
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 330000    think book classic childrens novel full fun fa...
# 330001    great book science fantasy look makes spinetin...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 330000        perfect child
# 330001    great book summer
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 330000    think book classic children novel full fun fan...
# 330001    great book science fantasy look make spineting...
# Name: Lemmatized review/text, dtype: object
# Processing rows 340000 to 350000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 340000     favorite new author
# 340001    spectacular riveting
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 340000    diane chamberlain new favorite author read boo...
# 340001    wonderful wonderful book wee hours finishing s...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 340000     favorite new author
# 340001    spectacular riveting
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 340000    diane chamberlain new favorite author read boo...
# 340001    wonderful wonderful book wee hour finish still...
# Name: Lemmatized review/text, dtype: object
# Processing rows 350000 to 360000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 350000       heartbreaking story
# 350001    night oprahs book club
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 350000    read many accounts holocaust think one cleares...
# 350001    could lay book finish made feel like telling s...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 350000         heartbreake story
# 350001    night oprahs book club
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 350000    read many account holocaust think one clear sh...
# 350001      could lay book finish make feel like tell story
# Name: Lemmatized review/text, dtype: object
# Processing rows 360000 to 370000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 360000    good read
# 360001     fun read
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 360000    fan mc beaton enjoyed agatha raisin books curi...
# 360001    characters endearing say leasti enjoyed look f...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 360000    good read
# 360001     fun read
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 360000    fan mc beaton enjoy agatha raisin book curious...
# 360001    character endear say leasti enjoy look forward...
# Name: Lemmatized review/text, dtype: object
# Processing rows 370000 to 380000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 370000             big liddell better digital form
# 370001    big liddel superior greekenglish lexicon
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 370000    big liddell valuable resource number reviewers...
# 370001    student classical koine greek edition quotlidd...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 370000               big liddell well digital form
# 370001    big liddel superior greekenglish lexicon
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 370000    big liddell valuable resource number reviewer ...
# 370001    student classical koine greek edition quotlidd...
# Name: Lemmatized review/text, dtype: object
# Processing rows 380000 to 390000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 380000    kripke proper names still thoroughly confused
# 380001                                         easy fun
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 380000    introthis book comprised lectures kripke gave ...
# 380001    actually many works written analytic philosoph...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 380000    kripke proper name still thoroughly confuse
# 380001                                       easy fun
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 380000    introthis book comprise lecture kripke give ja...
# 380001    actually many work write analytic philosopher ...
# Name: Lemmatized review/text, dtype: object
# Processing rows 390000 to 400000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 390000         lakeside cottage
# 390001    summer new beginnings
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 390000    liked book beginning really surprised took tot...
# 390001    romance like genre suggest choose another book...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 390000        lakeside cottage
# 390001    summer new beginning
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 390000    like book begin really surprised take totally ...
# 390001    romance like genre suggest choose another book...
# Name: Lemmatized review/text, dtype: object
# Processing rows 400000 to 410000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 400000        incomplete version
# 400001    quintessential romance
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 400000    love book reread nearly every year downloaded ...
# 400001    book speaks every romantic written beautifully...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 400000        incomplete version
# 400001    quintessential romance
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 400000    love book reread nearly every year download fr...
# 400001    book speak every romantic write beautifully cl...
# Name: Lemmatized review/text, dtype: object
# Processing rows 410000 to 420000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 410002                  hobbit
# 410003    expectedly fantastic
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 410002    good book listen driving bus songs really come...
# 410003    nothing unexpected way tolkien wrote adventure...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 410002                  hobbit
# 410003    expectedly fantastic
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 410002    good book listen drive bus song really come li...
# 410003    nothing unexpected way tolkien write adventure...
# Name: Lemmatized review/text, dtype: object
# Processing rows 420000 to 430000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 420000    true life experience
# 420001                big deal
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 420000    well read book twice nothing say contrary beli...
# 420001    beloved gets nomination overpraised work liter...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 420000    true life experience
# 420001                big deal
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 420000    well read book twice nothing say contrary beli...
# 420001    beloved get nomination overpraise work literat...
# Name: Lemmatized review/text, dtype: object
# Processing rows 430000 to 440000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 430000          good
# 430001    great book
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 430000    thought book enchanting wonderfully written re...
# 430001    series anecdotes woman husband school boys how...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 430000          good
# 430001    great book
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 430000    think book enchant wonderfully write read litt...
# 430001    series anecdotes woman husband school boy howe...
# Name: Lemmatized review/text, dtype: object
# Processing rows 440000 to 450000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 440000    grandfather mayada alaskari
# 440001        theres something snoopy
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 440000    recently met author mayada daughter iraq made ...
# 440001    friends charles schulz definitely gift looking...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 440000    grandfather mayada alaskari
# 440001       there s something snoopy
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 440000    recently meet author mayada daughter iraq make...
# 440001    friend charle schulz definitely gift look surf...
# Name: Lemmatized review/text, dtype: object
# Processing rows 450000 to 460000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 450000    entertaining cover cover
# 450001                electrifying
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 450000    good beach reading endlessly entertaining make...
# 450001    read lively charming book one sitting gilson u...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 450000    entertaining cover cover
# 450001                   electrify
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 450000    good beach reading endlessly entertaining make...
# 450001    read lively charming book one sit gilson use l...
# Name: Lemmatized review/text, dtype: object
# Processing rows 460000 to 470000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 460000    short stories diverge popular futuristic visions
# 460001                         excellent thought anthology
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 460000    lou anders edits live without net fine antholo...
# 460001    underlying premise eighteen story collection b...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 460000    short story diverge popular futuristic vision
# 460001                        excellent think anthology
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 460000    lou anders edit live without net fine antholog...
# 460001    underlie premise eighteen story collection bas...
# Name: Lemmatized review/text, dtype: object
# Processing rows 470000 to 480000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 470000    worthy inclusion short list literary classics
# 470001                           best fantasy ever read
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 470000    actually bought version lotr felt compelled wr...
# 470001    read lord rings times love way tolkien envirom...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 470000    worthy inclusion short list literary classic
# 470001                          good fantasy ever read
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 470000    actually buy version lotr felt compel write li...
# 470001    read lord ring times love way tolkien envirome...
# Name: Lemmatized review/text, dtype: object
# Processing rows 480000 to 490000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 480000       au contraire
# 480001    dont delay read
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 480000    red tent honest look eastern mediterranean wom...
# 480001    desire moved deeply feel connected history lif...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 480000         au contraire
# 480001    do not delay read
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 480000    red tent honest look eastern mediterranean wom...
# 480001    desire move deeply feel connected history life...
# Name: Lemmatized review/text, dtype: object
# Processing rows 490000 to 500000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 490000    death family
# 490001         classic
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 490000    surprise uplifting subject matter nevertheless...
# 490001    originally knoxville tn heard book whole life ...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 490000    death family
# 490001         classic
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 490000    surprise uplift subject matter nevertheless on...
# 490001    originally knoxville tn hear book whole life n...
# Name: Lemmatized review/text, dtype: object
# Processing rows 500000 to 510000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 500000    best study independence
# 500001
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 500000    people read adore books would well advised rea...
# 500001    plod bloated tome read summary id suggest summ...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 500000    good study independence
# 500001
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 500000    people read adore book would well advise read ...
# 500001    plod bloated tome read summary i d suggest sum...
# Name: Lemmatized review/text, dtype: object
# Processing rows 510000 to 520000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 510000    surprising saga
# 510001     enjoyable read
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 510000    excellent bookthe story robert louis stevenson...
# 510001    found book fast informative read neither light...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 510000    surprising saga
# 510001     enjoyable read
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 510000    excellent bookthe story robert louis stevenson...
# 510001    find book fast informative read neither lighth...
# Name: Lemmatized review/text, dtype: object
# Processing rows 520000 to 530000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 520000    great start
# 520001           good
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 520000    always forget much better books movies especia...
# 520001    started reading books bought complete collecti...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 520000    great start
# 520001           good
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 520000    always forget much well book movie especially ...
# 520001    start read book buy complete collection look f...
# Name: Lemmatized review/text, dtype: object
# Processing rows 530000 to 540000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 530000                 good story town runnymeade
# 530001    slow movingpreachyno comparison six one
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 530000    appears first juts wheezie series told juts da...
# 530001    read half book still nothing much happened fou...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 530000                 good story town runnymeade
# 530001    slow movingpreachyno comparison six one
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 530000    appear first juts wheezie series tell juts dau...
# 530001    read half book still nothing much happen find ...
# Name: Lemmatized review/text, dtype: object
# Processing rows 540000 to 550000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 540000    mccall smith delivers high intrigue unbridled ...
# 540001                      full cupboard life ladies detec
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 540000    return botswana quotthe fortunate countryquot ...
# 540001    subtitle quotmore samequot admirable character...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 540000    mccall smith deliver high intrigue unbridled r...
# 540001                        full cupboard life lady detec
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 540000    return botswana quotthe fortunate countryquot ...
# 540001    subtitle quotmore samequot admirable character...
# Name: Lemmatized review/text, dtype: object
# Processing rows 550000 to 560000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 550000    worth every cent going spend
# 550001                  beginner stuff
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 550000    book perfect overview vbscript scripting windo...
# 550001    nice book software developer system administra...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 550000    worth every cent go spend
# 550001               beginner stuff
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 550000    book perfect overview vbscript scripting windo...
# 550001    nice book software developer system administra...
# Name: Lemmatized review/text, dtype: object
# Processing rows 560000 to 570000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 560000        arabian enthusiest
# 560001    good coffee table book
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 560000    great title add ever growing arabian horse boo...
# 560001    book entrancing photos skips large number coun...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 560000           arabian enthusi
# 560001    good coffee table book
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 560000    great title add ever grow arabian horse book c...
# 560001    book entrance photo skip large number country ...
# Name: Lemmatized review/text, dtype: object
# Processing rows 570000 to 580000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 570000    awesome
# 570001       read
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 570000    amazing book first read book silly reason favo...
# 570001    catcher rye one favorite books first time read...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 570000    awesome
# 570001       read
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 570000    amazing book first read book silly reason favo...
# 570001    catcher rye one favorite book first time read ...
# Name: Lemmatized review/text, dtype: object
# Processing rows 580000 to 590000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 580000    enjoyed story
# 580001      fancy pants
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 580000    enjoyed story yes placed thought described era...
# 580001    susan elizabeth phillips auto buy one favorite...
# Name: Cleaned review/text, dtype: object
# Sample after lemmatization from column 'Lemmatized review/summary':
# 580000    enjoy story
# 580001     fancy pant
# Name: Lemmatized review/summary, dtype: object
# Sample after lemmatization from column 'Lemmatized review/text':
# 580000    enjoy story yes place think describe era well ...
# 580001    susan elizabeth phillips auto buy one favorite...
# Name: Lemmatized review/text, dtype: object
# Processing rows 590000 to 600000...
# Sample before lemmatization from column 'Cleaned review/summary':
# 590000       cant true
# 590001    bough breaks
# Name: Cleaned review/summary, dtype: object
# Sample before lemmatization from column 'Cleaned review/text':
# 590000    book rips door hinges backroom deals struck fb...
# 590001    leads could help exonerate bulger flemmi disre...
# Name: Cleaned review/text, dtype: object

# %%
df_rating[['Cleaned review/summary', 'Lemmatized review/summary', 'Cleaned review/text', 'Lemmatized review/text']].head()

# %%
df_rating.columns

# %%
# List of columns to drop
columns_to_drop = ['review/helpfulness']

# Drop the unnecessary columns with null values
df_rating = df_rating.drop(columns=columns_to_drop)

df_rating.columns

# %%
# Columns to include
columns_to_include = ['Cleaned Title', 'Lemmatized review/summary', 'Lemmatized review/text']
df_rating_subset = df_rating[columns_to_include]

# Save the subset to a CSV file
df_rating_subset.to_csv('Books_rating_cleaned.csv', index=False)
